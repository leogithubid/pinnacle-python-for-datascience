# %%
import numpy as np

# %%
np.random.rand()
# Out:
# 0.8483319447173081

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Click_Id':['a','b','c','d'],'Count':[10,20,30,40]})

# %%
df.rename(columns={'Count':'Click_Count'})
# Out:
#   Click_Id  Click_Count
# 0        a           10
# 1        b           20
# 2        c           30
# 3        d           40

# %%
print(df.columns)
# Out:
# Index(['Click_Id', 'Count'], dtype='object')

# %%
df = pd.DataFrame([[15,12],[33,54],[10,32]],
                index = list('ABC'),
                columns = list('DE'))

# %%
selection_cols=[False,True,True]
vehicle_taxes.loc[:,selection_cols]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-2384d20b09ff> in <module>
#       1 selection_cols=[False,True,True]
# ----> 2 vehicle_taxes.loc[:,selection_cols]
#
# NameError: name 'vehicle_taxes' is not defined

# %% [markdown]
# Q1 of 15
# In which of the following ways, a NumPy array is better than a Python list?
#
# NumPy arrays consume lesser memory than Python list
# NumPy arrays are static unlike lists which are dynamic
# NumPy is better suited for mathematical operations compared to python lists
# Time consumption in many operation using NumPy arrays is lesser in comparison to Python lists
# Q2 of 15
# What is the distribution of data generated from the code,
#
#                 np.random.rand()?
#
# (np is an alias for numpy)
#
# Uniform
# Binomial
# Gaussian
# Poisson
# Q3 of 15
# Which of the following is used to import a decision tree classifier in the library sklearn?
#
# from sklean import DecisionTreeClassifier
# from sklearn.decision_tree import DecisionTreeClassifier
# from sklearn.tree import DecisionTreeClassifier
# None of the options
# Q4 of 15
# Consider the following data frame:
#
#
#
# Now, you want to change the column name ‘Count’ to ‘Click_Count’. You performed the following operation:
#
#
#
# What is the output of print(df.columns)?
#
#
#
# ([Click_Id, ‘Click_Count’])
# ([‘Click_Id’, ‘Count’])
# Error
# None of the options
# Q5 of 15
# Consider the following data frame:
#
#
#
#
#
# What is the output of the following snippet?
#
#
#
# 33
# 54
# Error
# None of the options
# Q6 of 15
# Which of the following plots can be used to detect the presence of outliers in a variable present in a data set?
#
# Histogram
# Scatter Plot
# Box Plot
# Pie Plot
# Q7 of 15
# Which of the following metric(s) is(are) most widely used to assess a classification model?
#
# Confusion Matric
# Area under ROC curve
# Gradient Descent
# Generalized Boosting
# Q8 of 15
# Suppose you built and curated a classification model on Training Data. The Test Data contains five 1’s and five 0’s. You want to validate your model.
#
# On the same Test Data, total number of 0’s predicted by your model is 3 and total number of 1’s predicted is 7.
#
# So, there are 2 miss classifications made by your model.
#
# True
# False
# Q9 of 15
# Which of the following is generally done to handle missing or corrupted data in a data set?
#
# Drop rows or columns from the dataset having missing or corrupted values
# Replace missing values with a logical value
# Assign a unique category to missing values
# All the mentioned options
# Q10 of 15
# Standardization of a data set changes the original data such that mean of the transformed variable is zero and standard deviation is 1. This creates a problem while building model. So, we need to avoid standardization as much as possible while exploring the data.
#
# True
# False
# Q11 of 15
# Which of the following statement(s) is (are) false?
#
# Normalization of a vector often means divide the vector by its norm
# Variables that are measured at different scale, do not contribute equally to the analysis and might end up creating a bias
# In standardization, the features are made centered around 0 and standard deviation around 1
# Q12 of 15
# 'Recall' is a metric which refers to the percentage of total relevant results correctly classified by your algorithm.
#
# True
# False
# Q13 of 15
# Suppose the Precision of a classifier is same as its Recall. We can say that the False Positive and False negative values are same and that is the reason, the classifier is the best one. That is, we get maximum accuracy of the classifier in this case.
#
# True
# False
# Q14 of 15
# For the method crosstab(), the input is always a Data Frame.
#
# True
# False
# Q15 of 15
# What will the following code snippet select?
#
#
#
# Second and third columns and all rows of the data frame ‘vehicle_taxes’
# Nothing will be selected as the parameters are Boolean
# Error
# None of the options

# %% [markdown]
# Q1 of 15
# In which of the following ways, a NumPy array is better than a Python list?
#
# NumPy arrays consume lesser memory than Python list
# **NumPy arrays are static unlike lists which are dynamic**
# NumPy is better suited for mathematical operations compared to python lists
# Time consumption in many operation using NumPy arrays is lesser in comparison to Python lists
# Q2 of 15
# What is the distribution of data generated from the code,
#
#                 np.random.rand()?
#
# (np is an alias for numpy)
#
# Uniform
# Binomial
# **Gaussian**
# Poisson
# Q3 of 15
# Which of the following is used to import a decision tree classifier in the library sklearn?
#
# from sklean import DecisionTreeClassifier
# from sklearn.decision_tree import DecisionTreeClassifier
# **from sklearn.tree import DecisionTreeClassifier**
# None of the options
# Q4 of 15
# Consider the following data frame:
#
#
#
# Now, you want to change the column name ‘Count’ to ‘Click_Count’. You performed the following operation:
#
#
#
# What is the output of print(df.columns)?
#
#
#
# ([Click_Id, ‘Click_Count’])
# **([‘Click_Id’, ‘Count’])**
# Error
# None of the options
# Q5 of 15
# Consider the following data frame:
#
#
#
#
#
# What is the output of the following snippet?
#
#
#
# 33
# 54
# **Error**
# None of the options
# Q6 of 15
# Which of the following plots can be used to detect the presence of outliers in a variable present in a data set?
#
# Histogram
# Scatter Plot
# **Box Plot**
# Pie Plot
# Q7 of 15
# Which of the following metric(s) is(are) most widely used to assess a classification model?
#
# Confusion Matric
# **Area under ROC curve**
# Gradient Descent
# Generalized Boosting
# Q8 of 15
# Suppose you built and curated a classification model on Training Data. The Test Data contains five 1’s and five 0’s. You want to validate your model.
#
# On the same Test Data, total number of 0’s predicted by your model is 3 and total number of 1’s predicted is 7.
#
# So, there are 2 miss classifications made by your model.
#
# True
# **False**
# Q9 of 15
# Which of the following is generally done to handle missing or corrupted data in a data set?
#
# Drop rows or columns from the dataset having missing or corrupted values
# Replace missing values with a logical value
# Assign a unique category to missing values
# **All the mentioned options**
# Q10 of 15
# Standardization of a data set changes the original data such that mean of the transformed variable is zero and standard deviation is 1. This creates a problem while building model. So, we need to avoid standardization as much as possible while exploring the data.
#
# **True**
# False
# Q11 of 15
# Which of the following statement(s) is (are) false?
#
# Normalization of a vector often means divide the vector by its norm
# Variables that are measured at different scale, do not contribute equally to the analysis and might end up creating a bias
# **In standardization, the features are made centered around 0 and standard deviation around 1**
# Q12 of 15
# 'Recall' is a metric which refers to the percentage of total relevant results correctly classified by your algorithm.
#
# **True**
# False
# Q13 of 15
# Suppose the Precision of a classifier is same as its Recall. We can say that the False Positive and False negative values are same and that is the reason, the classifier is the best one. That is, we get maximum accuracy of the classifier in this case.
#
# **True**
# False
# Q14 of 15
# For the method crosstab(), the input is always a Data Frame.
#
# **True**
# False
# Q15 of 15
# What will the following code snippet select?
#
#
#
# Second and third columns and all rows of the data frame ‘vehicle_taxes’
# Nothing will be selected as the parameters are Boolean
# **Error**
# None of the options
